# %%
try:
  import qiskit
  import qiskit_aer
  import qiskit_nature
  import qiskit_ibm_runtime
  import pyscf
  import pylatexenc
except:
  # !pip install qiskit qiskit-aer qiskit-ibm-runtime qiskit_nature pyscf pylatexenc

# General imports
import numpy as np

# Qiskit Runtime
from qiskit.primitives import Estimator

# SciPy minimizer routine
from scipy.optimize import minimize

# Plotting functions
import matplotlib.pyplot as plt

# %%
from qiskit_nature.units import DistanceUnit
from qiskit_nature.second_q.drivers import PySCFDriver
from qiskit_nature.second_q.formats.molecule_info import MoleculeInfo
from qiskit_nature.second_q.transformers import FreezeCoreTransformer
from qiskit_nature.second_q.mappers import ParityMapper, JordanWignerMapper, BravyiKitaevMapper, InterleavedQubitMapper
from qiskit_nature.second_q.circuit.library import HartreeFock, UCCSD
from qiskit_algorithms.optimizers import SLSQP, SPSA, COBYLA
from qiskit_algorithms import NumPyMinimumEigensolver, VQE
from qiskit_aer.primitives import Sampler, Estimator


from datetime import datetime

# %%
dist = 1.0

# %%
# IMPORTANT
def draw_orbitals(problem):
    # Draw orbitals (method provided by Max)
    print(f'Number of particles : {problem.num_particles}')
    print(f'Number of spatial orbitals : {problem.num_spatial_orbitals}')
    print(f'Orbital energies : {problem.orbital_energies}')

    fig, ax = plt.subplots(1, 1, figsize=(16, 10))

    for i in range(problem.num_spatial_orbitals):
        if problem.orbital_occupations[i] == 1:
            co = 'tab:blue'
        else:
            co = 'tab:green'

        ax.scatter(i,np.log10(np.abs(problem.orbital_energies[i])), s=15, c=co, marker='o')

    ax.set_xlabel('Orbital', fontsize=15)
    ax.set_ylabel(r'$\log\left(|E|\right)$', fontsize=15)

    ax.scatter(-2,2,s=15, c='tab:blue', marker='o', label='Occupied orbitals')
    ax.scatter(-2,2,s=15, c='tab:green', marker='o', label='Empty orbitals')
    ax.set_xlim(-0.2,problem.num_spatial_orbitals+0.2)
    ax.set_ylim(np.amin(np.log10(np.abs(problem.orbital_energies)))-0.2,
                np.amax(np.log10(np.abs(problem.orbital_energies)))+0.2)
    ax.legend(loc='best', fontsize=15)

def get_freezed_problem(properties, indexes = None):
    # Shortcut for the problem definition
    return FreezeCoreTransformer(
        freeze_core=True, remove_orbitals=indexes
    ).transform(properties)

# %% [markdown]
# ## other funcs copied

# %%
def exact_solver(qubit_op, problem):
  sol = NumPyMinimumEigensolver().compute_minimum_eigenvalue(qubit_op)
  result = problem.interpret(sol)
  return result

# %% [markdown]
# ## func for convenient experimental loop

# %%
def Experiment(
  molecule,
  orbitals_to_fix,
  optimizer=COBYLA(maxiter=15, tol=0.0001),
  output_info=True,
  if_draw_orbitals=False,
):
  '''
  returns pair of (exact energy, vqe energy)
  '''
  print(f'= = = = = = = = = = = = = = = = = = = = = = = =\nExperiment started: {(datetime.now().time()).strftime("%H:%M:%S")}')  

  molecule = "".join(molecule)[:-1]
  driver = PySCFDriver(
      atom=molecule,
      unit=DistanceUnit.ANGSTROM,
      basis='sto3g',
      spin=0
  )
  properties_molecule = driver.run()
    
  problem = get_freezed_problem(properties_molecule, orbitals_to_fix)

  if (if_draw_orbitals):
    draw_orbitals(problem)
  if (output_info):
    print('. . . . . . . . . . . . . . . . . . .\n')
  
  # exact solver
  estimator = Estimator(approximation=True)
  num_particles = problem.num_particles
  num_spatial_orbitals = problem.num_spatial_orbitals
  mapper = ParityMapper(num_particles=num_particles)
  # mapper = JordanWignerMapper()
  qubit_op = mapper.map(problem.second_q_ops()[0])
  
  exact_result = exact_solver(qubit_op, problem)
  if (output_info):
    print(exact_result)
    print(f'Exact solver done: {(datetime.now().time()).strftime("%H:%M:%S")}')
  
  
  # VQE
  init_state = HartreeFock(num_spatial_orbitals, num_particles, mapper)
  # TODO: maybe try EfficientSU2 instead of UCCSD
  ansatz = UCCSD(
      num_spatial_orbitals, num_particles, mapper, initial_state=init_state
  )
  if (output_info):
    current_time = datetime.now().time()
    print(f'ansatz initialized, {current_time.strftime("%H:%M:%S")}')
    print(f'ansatz.depth = {ansatz.depth()}')
    print(f'num of qubits = {ansatz.num_qubits}')
  
  vqe = VQE(
        estimator,
        ansatz,
        optimizer,
        initial_point=[0] * ansatz.num_parameters,
    )
  vqe_calc = vqe.compute_minimum_eigenvalue(qubit_op)
  if (output_info):
    current_time = datetime.now().time()
    print(f'VQE compute_minimum_eigenvalue done, {current_time.strftime("%H:%M:%S")}')

  vqe_result = problem.interpret(vqe_calc)
  if (output_info):
    print(
      f"VQE Result: {vqe_result}\n",
      f"Exact Energy: {exact_result}\n"
    )
  return (exact_result, vqe_result)

# %%
lioh_dist_domain = np.linspace(1.4, 1.6, 50)

exact_energies = []
vqe_energies = []

for dist in lioh_dist_domain:
  molecule = [
    'Li .0 .0 .0;',
    'H '+str(dist)+' .0 .0;',
    ]
  print(f"{dist = }")
  exact_val, vqe_val = Experiment(molecule=molecule, optimizer=COBYLA(maxiter=60, tol=0.0001), orbitals_to_fix=[5], if_draw_orbitals=False)
  exact_energies.append(exact_val)
  vqe_energies.append(vqe_val)
# Out:
# dist = np.float64(1.4)
# = = = = = = = = = = = = = = = = = = = = = = = =
# Experiment started: 21:30:48
# . . . . . . . . . . . . . . . . . . .
#
# === GROUND STATE ENERGY ===
#
# * Electronic ground state energy (Hartree): -8.996385766816
#   - computed part:      -1.105594282834
#   - FreezeCoreTransformer extracted energy part: -7.890791483981
# ~ Nuclear repulsion energy (Hartree): 1.133951166257
# > Total ground state energy (Hartree): -7.862434600559
#
# === MEASURED OBSERVABLES ===
#
#
# === DIPOLE MOMENTS ===
#
# ~ Nuclear dipole moment (a.u.): [2.64561657  0.0  0.0]
#
# Exact solver done: 21:30:50
# ansatz initialized, 21:30:50
# ansatz.depth = 1
# num of qubits = 6
# VQE compute_minimum_eigenvalue done, 21:30:55
# VQE Result: === GROUND STATE ENERGY ===
#
# * Electronic ground state energy (Hartree): -8.995044433077
#   - computed part:      -1.104252949096
#   - FreezeCoreTransformer extracted energy part: -7.890791483981
# ~ Nuclear repulsion energy (Hartree): 1.133951166257
# > Total ground state energy (Hartree): -7.86109326682
#
# === MEASURED OBSERVABLES ===
#
#
# === DIPOLE MOMENTS ===
#
# ~ Nuclear dipole moment (a.u.): [2.64561657  0.0  0.0]
#
#  Exact Energy: === GROUND STATE ENERGY ===
#
# * Electronic ground state energy (Hartree): -8.996385766816
#   - computed part:      -1.105594282834
#   - FreezeCoreTransformer extracted energy part: -7.890791483981
# ~ Nuclear repulsion energy (Hartree): 1.133951166257
# > Total ground state energy (Hartree): -7.862434600559
#
# === MEASURED OBSERVABLES ===
#
#
# === DIPOLE MOMENTS ===
#
# ~ Nuclear dipole moment (a.u.): [2.64561657  0.0  0.0]
#
#
# dist = np.float64(1.4040816326530612)
# = = = = = = = = = = = = = = = = = = = = = = = =
# Experiment started: 21:30:55
# . . . . . . . . . . . . . . . . . . .
#
# === GROUND STATE ENERGY ===
#
# * Electronic ground state energy (Hartree): -8.993303560605
#   - computed part:      -1.104716224374
#   - FreezeCoreTransformer extracted energy part: -7.888587336231
# ~ Nuclear repulsion energy (Hartree): 1.130654796588
# > Total ground state energy (Hartree): -7.862648764017
#
# === MEASURED OBSERVABLES ===
#
#
# === DIPOLE MOMENTS ===
#
# ~ Nuclear dipole moment (a.u.): [2.65332974  0.0  0.0]
#
# Exact solver done: 21:30:56
# ansatz initialized, 21:30:56
# ansatz.depth = 1
# num of qubits = 6
# VQE compute_minimum_eigenvalue done, 21:31:01
# VQE Result: === GROUND STATE ENERGY ===
#
# * Electronic ground state energy (Hartree): -8.99228987277
#   - computed part:      -1.103702536539
#   - FreezeCoreTransformer extracted energy part: -7.888587336231
# ~ Nuclear repulsion energy (Hartree): 1.130654796588
# > Total ground state energy (Hartree): -7.861635076183
#
# === MEASURED OBSERVABLES ===
#
#
# === DIPOLE MOMENTS ===
#
# ~ Nuclear dipole moment (a.u.): [2.65332974  0.0  0.0]
#
#  Exact Energy: === GROUND STATE ENERGY ===
#
# * Electronic ground state energy (Hartree): -8.993303560605
#   - computed part:      -1.104716224374
#   - FreezeCoreTransformer extracted energy part: -7.888587336231
# ~ Nuclear repulsion energy (Hartree): 1.130654796588
# > Total ground state energy (Hartree): -7.862648764017
#
# === MEASURED OBSERVABLES ===
#
#
# === DIPOLE MOMENTS ===
#
# ~ Nuclear dipole moment (a.u.): [2.65332974  0.0  0.0]
#
#
# dist = np.float64(1.4081632653061225)
# = = = = = = = = = = = = = = = = = = = = = = = =
# Experiment started: 21:31:01
# . . . . . . . . . . . . . . . . . . .
#
# === GROUND STATE ENERGY ===
#
# * Electronic ground state energy (Hartree): -8.990231074723
#   - computed part:      -1.103834839093
#   - FreezeCoreTransformer extracted energy part: -7.88639623563
# ~ Nuclear repulsion energy (Hartree): 1.127377536308
# > Total ground state energy (Hartree): -7.862853538415
#
# === MEASURED OBSERVABLES ===
#
#
# === DIPOLE MOMENTS ===
#
# ~ Nuclear dipole moment (a.u.): [2.66104291  0.0  0.0]
#
# Exact solver done: 21:31:03
# ansatz initialized, 21:31:03
# ansatz.depth = 1
# num of qubits = 6
# VQE compute_minimum_eigenvalue done, 21:31:07
# VQE Result: === GROUND STATE ENERGY ===
#
# * Electronic ground state energy (Hartree): -8.989117082963
#   - computed part:      -1.102720847334
#   - FreezeCoreTransformer extracted energy part: -7.88639623563
# ~ Nuclear repulsion energy (Hartree): 1.127377536308
# > Total ground state energy (Hartree): -7.861739546656
#
# === MEASURED OBSERVABLES ===
#
#
# === DIPOLE MOMENTS ===
#
# ~ Nuclear dipole moment (a.u.): [2.66104291  0.0  0.0]
#
#  Exact Energy: === GROUND STATE ENERGY ===
#
# * Electronic ground state energy (Hartree): -8.990231074723
#   - computed part:      -1.103834839093
#   - FreezeCoreTransformer extracted energy part: -7.88639623563
# ~ Nuclear repulsion energy (Hartree): 1.127377536308
# > Total ground state energy (Hartree): -7.862853538415
#
# === MEASURED OBSERVABLES ===
#
#
# === DIPOLE MOMENTS ===
#
# ~ Nuclear dipole moment (a.u.): [2.66104291  0.0  0.0]
#
#
# dist = np.float64(1.4122448979591835)
# = = = = = = = = = = = = = = = = = = = = = = = =
# Experiment started: 21:31:07
# . . . . . . . . . . . . . . . . . . .
#
# === GROUND STATE ENERGY ===
#
# * Electronic ground state energy (Hartree): -8.987168254882
#   - computed part:      -1.102950190981
#   - FreezeCoreTransformer extracted energy part: -7.884218063901
# ~ Nuclear repulsion energy (Hartree): 1.124119219729
# > Total ground state energy (Hartree): -7.863049035153
#
# === MEASURED OBSERVABLES ===
#
#
# === DIPOLE MOMENTS ===
#
# ~ Nuclear dipole moment (a.u.): [2.66875608  0.0  0.0]
#
# Exact solver done: 21:31:08
# ansatz initialized, 21:31:08
# ansatz.depth = 1
# num of qubits = 6
# VQE compute_minimum_eigenvalue done, 21:31:13
# VQE Result: === GROUND STATE ENERGY ===
#
# * Electronic ground state energy (Hartree): -8.986868680044
#   - computed part:      -1.102650616143
#   - FreezeCoreTransformer extracted energy part: -7.884218063901
# ~ Nuclear repulsion energy (Hartree): 1.124119219729
# > Total ground state energy (Hartree): -7.862749460315
#
# === MEASURED OBSERVABLES ===
#
#
# === DIPOLE MOMENTS ===
#
# ~ Nuclear dipole moment (a.u.): [2.66875608  0.0  0.0]
#
#  Exact Energy: === GROUND STATE ENERGY ===
#
# * Electronic ground state energy (Hartree): -8.987168254882
#   - computed part:      -1.102950190981
#   - FreezeCoreTransformer extracted energy part: -7.884218063901
# ~ Nuclear repulsion energy (Hartree): 1.124119219729
# > Total ground state energy (Hartree): -7.863049035153
#
# === MEASURED OBSERVABLES ===
#
#
# === DIPOLE MOMENTS ===
#
# ~ Nuclear dipole moment (a.u.): [2.66875608  0.0  0.0]
#
#
# dist = np.float64(1.4163265306122448)
# = = = = = = = = = = = = = = = = = = = = = = = =
# Experiment started: 21:31:13
# . . . . . . . . . . . . . . . . . . .
#
# === GROUND STATE ENERGY ===
#
# * Electronic ground state energy (Hartree): -8.98411504732
#   - computed part:      -1.102062343128
#   - FreezeCoreTransformer extracted energy part: -7.882052704192
# ~ Nuclear repulsion energy (Hartree): 1.120879683073
# > Total ground state energy (Hartree): -7.863235364247
#
# === MEASURED OBSERVABLES ===
#
#
# === DIPOLE MOMENTS ===
#
# ~ Nuclear dipole moment (a.u.): [2.67646925  0.0  0.0]
#
# Exact solver done: 21:31:14
# ansatz initialized, 21:31:14
# ansatz.depth = 1
# num of qubits = 6
# VQE compute_minimum_eigenvalue done, 21:31:19
# VQE Result: === GROUND STATE ENERGY ===
#
# * Electronic ground state energy (Hartree): -8.98366201081
#   - computed part:      -1.101609306618
#   - FreezeCoreTransformer extracted energy part: -7.882052704192
# ~ Nuclear repulsion energy (Hartree): 1.120879683073
# > Total ground state energy (Hartree): -7.862782327737
#
# === MEASURED OBSERVABLES ===
#
#
# === DIPOLE MOMENTS ===
#
# ~ Nuclear dipole moment (a.u.): [2.67646925  0.0  0.0]
#
#  Exact Energy: === GROUND STATE ENERGY ===
#
# * Electronic ground state energy (Hartree): -8.98411504732
#   - computed part:      -1.102062343128
#   - FreezeCoreTransformer extracted energy part: -7.882052704192
# ~ Nuclear repulsion energy (Hartree): 1.120879683073
# > Total ground state energy (Hartree): -7.863235364247
#
# === MEASURED OBSERVABLES ===
#
#
# === DIPOLE MOMENTS ===
#
# ~ Nuclear dipole moment (a.u.): [2.67646925  0.0  0.0]
#
#
# dist = np.float64(1.420408163265306)
# = = = = = = = = = = = = = = = = = = = = = = = =
# Experiment started: 21:31:19
# . . . . . . . . . . . . . . . . . . .
#
# === GROUND STATE ENERGY ===
#
# * Electronic ground state energy (Hartree): -8.981071398794
#   - computed part:      -1.101171357743
#   - FreezeCoreTransformer extracted energy part: -7.879900041051
# ~ Nuclear repulsion energy (Hartree): 1.117658764443
# > Total ground state energy (Hartree): -7.863412634351
#
# === MEASURED OBSERVABLES ===
#
#
# === DIPOLE MOMENTS ===
#
# ~ Nuclear dipole moment (a.u.): [2.68418241  0.0  0.0]
#
# Exact solver done: 21:31:20
# ansatz initialized, 21:31:20
# ansatz.depth = 1
# num of qubits = 6
# VQE compute_minimum_eigenvalue done, 21:31:24
# VQE Result: === GROUND STATE ENERGY ===
#
# * Electronic ground state energy (Hartree): -8.980658094366
#   - computed part:      -1.100758053314
#   - FreezeCoreTransformer extracted energy part: -7.879900041051
# ~ Nuclear repulsion energy (Hartree): 1.117658764443
# > Total ground state energy (Hartree): -7.862999329923
#
# === MEASURED OBSERVABLES ===
#
#
# === DIPOLE MOMENTS ===
#
# ~ Nuclear dipole moment (a.u.): [2.68418241  0.0  0.0]
#
#  Exact Energy: === GROUND STATE ENERGY ===
#
# * Electronic ground state energy (Hartree): -8.981071398794
#   - computed part:      -1.101171357743
#   - FreezeCoreTransformer extracted energy part: -7.879900041051
# ~ Nuclear repulsion energy (Hartree): 1.117658764443
# > Total ground state energy (Hartree): -7.863412634351
#
# === MEASURED OBSERVABLES ===
#
#
# === DIPOLE MOMENTS ===
#
# ~ Nuclear dipole moment (a.u.): [2.68418241  0.0  0.0]
#
#
# dist = np.float64(1.4244897959183673)
# = = = = = = = = = = = = = = = = = = = = = = = =
# Experiment started: 21:31:24
# . . . . . . . . . . . . . . . . . . .
#
# === GROUND STATE ENERGY ===
#
# * Electronic ground state energy (Hartree): -8.978037256575
#   - computed part:      -1.100277296163
#   - FreezeCoreTransformer extracted energy part: -7.877759960411
# ~ Nuclear repulsion energy (Hartree): 1.1144563038
# > Total ground state energy (Hartree): -7.863580952775
#
# === MEASURED OBSERVABLES ===
#
#
# === DIPOLE MOMENTS ===
#
# ~ Nuclear dipole moment (a.u.): [2.69189558  0.0  0.0]
#
# Exact solver done: 21:31:25
# ansatz initialized, 21:31:26
# ansatz.depth = 1
# num of qubits = 6
# VQE compute_minimum_eigenvalue done, 21:31:30
# VQE Result: === GROUND STATE ENERGY ===
#
# * Electronic ground state energy (Hartree): -8.976857426507
#   - computed part:      -1.099097466096
#   - FreezeCoreTransformer extracted energy part: -7.877759960411
# ~ Nuclear repulsion energy (Hartree): 1.1144563038
# > Total ground state energy (Hartree): -7.862401122707
#
# === MEASURED OBSERVABLES ===
#
#
# === DIPOLE MOMENTS ===
#
# ~ Nuclear dipole moment (a.u.): [2.69189558  0.0  0.0]
#
#  Exact Energy: === GROUND STATE ENERGY ===
#
# * Electronic ground state energy (Hartree): -8.978037256575
#   - computed part:      -1.100277296163
#   - FreezeCoreTransformer extracted energy part: -7.877759960411
# ~ Nuclear repulsion energy (Hartree): 1.1144563038
# > Total ground state energy (Hartree): -7.863580952775
#
# === MEASURED OBSERVABLES ===
#
#
# === DIPOLE MOMENTS ===
#
# ~ Nuclear dipole moment (a.u.): [2.69189558  0.0  0.0]
#
#
# dist = np.float64(1.4285714285714286)
# = = = = = = = = = = = = = = = = = = = = = = = =
# Experiment started: 21:31:30
# . . . . . . . . . . . . . . . . . . .
#
# === GROUND STATE ENERGY ===
#
# * Electronic ground state energy (Hartree): -8.975012568439
#   - computed part:      -1.099380218872
#   - FreezeCoreTransformer extracted energy part: -7.875632349567
# ~ Nuclear repulsion energy (Hartree): 1.111272142932
# > Total ground state energy (Hartree): -7.863740425507
#
# === MEASURED OBSERVABLES ===
#
#
# === DIPOLE MOMENTS ===
#
# ~ Nuclear dipole moment (a.u.): [2.69960875  0.0  0.0]
#
# Exact solver done: 21:31:31
# ansatz initialized, 21:31:31
# ansatz.depth = 1
# num of qubits = 6
# VQE compute_minimum_eigenvalue done, 21:31:35
# VQE Result: === GROUND STATE ENERGY ===
#
# * Electronic ground state energy (Hartree): -8.97478500601
#   - computed part:      -1.099152656443
#   - FreezeCoreTransformer extracted energy part: -7.875632349567
# ~ Nuclear repulsion energy (Hartree): 1.111272142932
# > Total ground state energy (Hartree): -7.863512863078
#
# === MEASURED OBSERVABLES ===
#
#
# === DIPOLE MOMENTS ===
#
# ~ Nuclear dipole moment (a.u.): [2.69960875  0.0  0.0]
#
#  Exact Energy: === GROUND STATE ENERGY ===
#
# * Electronic ground state energy (Hartree): -8.975012568439
#   - computed part:      -1.099380218872
#   - FreezeCoreTransformer extracted energy part: -7.875632349567
# ~ Nuclear repulsion energy (Hartree): 1.111272142932
# > Total ground state energy (Hartree): -7.863740425507
#
# === MEASURED OBSERVABLES ===
#
#
# === DIPOLE MOMENTS ===
#
# ~ Nuclear dipole moment (a.u.): [2.69960875  0.0  0.0]
#
#
# dist = np.float64(1.4326530612244897)
# = = = = = = = = = = = = = = = = = = = = = = = =
# Experiment started: 21:31:35
# . . . . . . . . . . . . . . . . . . .
#
# === GROUND STATE ENERGY ===
#
# * Electronic ground state energy (Hartree): -8.971997282666
#   - computed part:      -1.098480185508
#   - FreezeCoreTransformer extracted energy part: -7.873517097158
# ~ Nuclear repulsion energy (Hartree): 1.108106125431
# > Total ground state energy (Hartree): -7.863891157236
#
# === MEASURED OBSERVABLES ===
#
#
# === DIPOLE MOMENTS ===
#
# ~ Nuclear dipole moment (a.u.): [2.70732192  0.0  0.0]
#
# Exact solver done: 21:31:36
# ansatz initialized, 21:31:37
# ansatz.depth = 1
# num of qubits = 6
# VQE compute_minimum_eigenvalue done, 21:31:41
# VQE Result: === GROUND STATE ENERGY ===
#
# * Electronic ground state energy (Hartree): -8.971670516567
#   - computed part:      -1.098153419409
#   - FreezeCoreTransformer extracted energy part: -7.873517097158
# ~ Nuclear repulsion energy (Hartree): 1.108106125431
# > Total ground state energy (Hartree): -7.863564391136
#
# === MEASURED OBSERVABLES ===
#
#
# === DIPOLE MOMENTS ===
#
# ~ Nuclear dipole moment (a.u.): [2.70732192  0.0  0.0]
#
#  Exact Energy: === GROUND STATE ENERGY ===
#
# * Electronic ground state energy (Hartree): -8.971997282666
#   - computed part:      -1.098480185508
#   - FreezeCoreTransformer extracted energy part: -7.873517097158
# ~ Nuclear repulsion energy (Hartree): 1.108106125431
# > Total ground state energy (Hartree): -7.863891157236
#
# === MEASURED OBSERVABLES ===
#
#
# === DIPOLE MOMENTS ===
#
# ~ Nuclear dipole moment (a.u.): [2.70732192  0.0  0.0]
#
#
# dist = np.float64(1.436734693877551)
# = = = = = = = = = = = = = = = = = = = = = = = =
# Experiment started: 21:31:41
# . . . . . . . . . . . . . . . . . . .
#
# === GROUND STATE ENERGY ===
#
# * Electronic ground state energy (Hartree): -8.968991348029
#   - computed part:      -1.097577254879
#   - FreezeCoreTransformer extracted energy part: -7.87141409315
# ~ Nuclear repulsion energy (Hartree): 1.104958096665
# > Total ground state energy (Hartree): -7.864033251364
#
# === MEASURED OBSERVABLES ===
#
#
# === DIPOLE MOMENTS ===
#
# ~ Nuclear dipole moment (a.u.): [2.71503509  0.0  0.0]
#
# Exact solver done: 21:31:42
# ansatz initialized, 21:31:42
# ansatz.depth = 1
# num of qubits = 6
# VQE compute_minimum_eigenvalue done, 21:31:46
# VQE Result: === GROUND STATE ENERGY ===
#
# * Electronic ground state energy (Hartree): -8.968678224862
#   - computed part:      -1.097264131712
#   - FreezeCoreTransformer extracted energy part: -7.87141409315
# ~ Nuclear repulsion energy (Hartree): 1.104958096665
# > Total ground state energy (Hartree): -7.863720128196
#
# === MEASURED OBSERVABLES ===
#
#
# === DIPOLE MOMENTS ===
#
# ~ Nuclear dipole moment (a.u.): [2.71503509  0.0  0.0]
#
#  Exact Energy: === GROUND STATE ENERGY ===
#
# * Electronic ground state energy (Hartree): -8.968991348029
#   - computed part:      -1.097577254879
#   - FreezeCoreTransformer extracted energy part: -7.87141409315
# ~ Nuclear repulsion energy (Hartree): 1.104958096665
# > Total ground state energy (Hartree): -7.864033251364
#
# === MEASURED OBSERVABLES ===
#
#
# === DIPOLE MOMENTS ===
#
# ~ Nuclear dipole moment (a.u.): [2.71503509  0.0  0.0]
#
#
# dist = np.float64(1.4408163265306122)
# = = = = = = = = = = = = = = = = = = = = = = = =
# Experiment started: 21:31:46
# . . . . . . . . . . . . . . . . . . .
#
# === GROUND STATE ENERGY ===
#
# * Electronic ground state energy (Hartree): -8.96599471379
#   - computed part:      -1.096671484976
#   - FreezeCoreTransformer extracted energy part: -7.869323228813
# ~ Nuclear repulsion energy (Hartree): 1.101827903757
# > Total ground state energy (Hartree): -7.864166810033
#
# === MEASURED OBSERVABLES ===
#
#
# === DIPOLE MOMENTS ===
#
# ~ Nuclear dipole moment (a.u.): [2.72274825  0.0  0.0]
#
# Exact solver done: 21:31:47
# ansatz initialized, 21:31:48
# ansatz.depth = 1
# num of qubits = 6
# VQE compute_minimum_eigenvalue done, 21:31:52
# VQE Result: === GROUND STATE ENERGY ===
#
# * Electronic ground state energy (Hartree): -8.965490816077
#   - computed part:      -1.096167587264
#   - FreezeCoreTransformer extracted energy part: -7.869323228813
# ~ Nuclear repulsion energy (Hartree): 1.101827903757
# > Total ground state energy (Hartree): -7.86366291232
#
# === MEASURED OBSERVABLES ===
#
#
# === DIPOLE MOMENTS ===
#
# ~ Nuclear dipole moment (a.u.): [2.72274825  0.0  0.0]
#
#  Exact Energy: === GROUND STATE ENERGY ===
#
# * Electronic ground state energy (Hartree): -8.96599471379
#   - computed part:      -1.096671484976
#   - FreezeCoreTransformer extracted energy part: -7.869323228813
# ~ Nuclear repulsion energy (Hartree): 1.101827903757
# > Total ground state energy (Hartree): -7.864166810033
#
# === MEASURED OBSERVABLES ===
#
#
# === DIPOLE MOMENTS ===
#
# ~ Nuclear dipole moment (a.u.): [2.72274825  0.0  0.0]
#
#
# dist = np.float64(1.4448979591836735)
# = = = = = = = = = = = = = = = = = = = = = = = =
# Experiment started: 21:31:52
# . . . . . . . . . . . . . . . . . . .
#
# === GROUND STATE ENERGY ===
#
# * Electronic ground state energy (Hartree): -8.963007329694
#   - computed part:      -1.095762932986
#   - FreezeCoreTransformer extracted energy part: -7.867244396708
# ~ Nuclear repulsion energy (Hartree): 1.098715395554
# > Total ground state energy (Hartree): -7.86429193414
#
# === MEASURED OBSERVABLES ===
#
#
# === DIPOLE MOMENTS ===
#
# ~ Nuclear dipole moment (a.u.): [2.73046142  0.0  0.0]
#
# Exact solver done: 21:31:53
# ansatz initialized, 21:31:53
# ansatz.depth = 1
# num of qubits = 6
# VQE compute_minimum_eigenvalue done, 21:31:57
# VQE Result: === GROUND STATE ENERGY ===
#
# * Electronic ground state energy (Hartree): -8.962536375457
#   - computed part:      -1.095291978749
#   - FreezeCoreTransformer extracted energy part: -7.867244396708
# ~ Nuclear repulsion energy (Hartree): 1.098715395554
# > Total ground state energy (Hartree): -7.863820979902
#
# === MEASURED OBSERVABLES ===
#
#
# === DIPOLE MOMENTS ===
#
# ~ Nuclear dipole moment (a.u.): [2.73046142  0.0  0.0]
#
#  Exact Energy: === GROUND STATE ENERGY ===
#
# * Electronic ground state energy (Hartree): -8.963007329694
#   - computed part:      -1.095762932986
#   - FreezeCoreTransformer extracted energy part: -7.867244396708
# ~ Nuclear repulsion energy (Hartree): 1.098715395554
# > Total ground state energy (Hartree): -7.86429193414
#
# === MEASURED OBSERVABLES ===
#
#
# === DIPOLE MOMENTS ===
#
# ~ Nuclear dipole moment (a.u.): [2.73046142  0.0  0.0]
#
#
# dist = np.float64(1.4489795918367347)
# = = = = = = = = = = = = = = = = = = = = = = = =
# Experiment started: 21:31:57
# . . . . . . . . . . . . . . . . . . .
#
# === GROUND STATE ENERGY ===
#
# * Electronic ground state energy (Hartree): -8.960029145966
#   - computed part:      -1.094851655302
#   - FreezeCoreTransformer extracted energy part: -7.865177490664
# ~ Nuclear repulsion energy (Hartree): 1.095620422609
# > Total ground state energy (Hartree): -7.864408723357
#
# === MEASURED OBSERVABLES ===
#
#
# === DIPOLE MOMENTS ===
#
# ~ Nuclear dipole moment (a.u.): [2.73817459  0.0  0.0]
#
# Exact solver done: 21:31:58
# ansatz initialized, 21:31:59
# ansatz.depth = 1
# num of qubits = 6
# VQE compute_minimum_eigenvalue done, 21:32:03
# VQE Result: === GROUND STATE ENERGY ===
#
# * Electronic ground state energy (Hartree): -8.959751362137
#   - computed part:      -1.094573871473
#   - FreezeCoreTransformer extracted energy part: -7.865177490664
# ~ Nuclear repulsion energy (Hartree): 1.095620422609
# > Total ground state energy (Hartree): -7.864130939528
#
# === MEASURED OBSERVABLES ===
#
#
# === DIPOLE MOMENTS ===
#
# ~ Nuclear dipole moment (a.u.): [2.73817459  0.0  0.0]
#
#  Exact Energy: === GROUND STATE ENERGY ===
#
# * Electronic ground state energy (Hartree): -8.960029145966
#   - computed part:      -1.094851655302
#   - FreezeCoreTransformer extracted energy part: -7.865177490664
# ~ Nuclear repulsion energy (Hartree): 1.095620422609
# > Total ground state energy (Hartree): -7.864408723357
#
# === MEASURED OBSERVABLES ===
#
#
# === DIPOLE MOMENTS ===
#
# ~ Nuclear dipole moment (a.u.): [2.73817459  0.0  0.0]
#
#
# dist = np.float64(1.4530612244897958)
# = = = = = = = = = = = = = = = = = = = = = = = =
# Experiment started: 21:32:03
# . . . . . . . . . . . . . . . . . . .
#
# === GROUND STATE ENERGY ===
#
# * Electronic ground state energy (Hartree): -8.957060113299
#   - computed part:      -1.093937707535
#   - FreezeCoreTransformer extracted energy part: -7.863122405764
# ~ Nuclear repulsion energy (Hartree): 1.092542837152
# > Total ground state energy (Hartree): -7.864517276147
#
# === MEASURED OBSERVABLES ===
#
#
# === DIPOLE MOMENTS ===
#
# ~ Nuclear dipole moment (a.u.): [2.74588776  0.0  0.0]
#
# Exact solver done: 21:32:04
# ansatz initialized, 21:32:04
# ansatz.depth = 1
# num of qubits = 6
# VQE compute_minimum_eigenvalue done, 21:32:09
# VQE Result: === GROUND STATE ENERGY ===
#
# * Electronic ground state energy (Hartree): -8.95630857338
#   - computed part:      -1.093186167616
#   - FreezeCoreTransformer extracted energy part: -7.863122405764
# ~ Nuclear repulsion energy (Hartree): 1.092542837152
# > Total ground state energy (Hartree): -7.863765736227
#
# === MEASURED OBSERVABLES ===
#
#
# === DIPOLE MOMENTS ===
#
# ~ Nuclear dipole moment (a.u.): [2.74588776  0.0  0.0]
#
#  Exact Energy: === GROUND STATE ENERGY ===
#
# * Electronic ground state energy (Hartree): -8.957060113299
#   - computed part:      -1.093937707535
#   - FreezeCoreTransformer extracted energy part: -7.863122405764
# ~ Nuclear repulsion energy (Hartree): 1.092542837152
# > Total ground state energy (Hartree): -7.864517276147
#
# === MEASURED OBSERVABLES ===
#
#
# === DIPOLE MOMENTS ===
#
# ~ Nuclear dipole moment (a.u.): [2.74588776  0.0  0.0]
#
#
# dist = np.float64(1.457142857142857)
# = = = = = = = = = = = = = = = = = = = = = = = =
# Experiment started: 21:32:09
# . . . . . . . . . . . . . . . . . . .
#
# === GROUND STATE ENERGY ===
#
# * Electronic ground state energy (Hartree): -8.954100182855
#   - computed part:      -1.093021144531
#   - FreezeCoreTransformer extracted energy part: -7.861079038324
# ~ Nuclear repulsion energy (Hartree): 1.089482493071
# > Total ground state energy (Hartree): -7.864617689785
#
# === MEASURED OBSERVABLES ===
#
#
# === DIPOLE MOMENTS ===
#
# ~ Nuclear dipole moment (a.u.): [2.75360092  0.0  0.0]
#
# Exact solver done: 21:32:10
# ansatz initialized, 21:32:10
# ansatz.depth = 1
# num of qubits = 6
# VQE compute_minimum_eigenvalue done, 21:32:14
# VQE Result: === GROUND STATE ENERGY ===
#
# * Electronic ground state energy (Hartree): -8.953838654272
#   - computed part:      -1.092759615948
#   - FreezeCoreTransformer extracted energy part: -7.861079038324
# ~ Nuclear repulsion energy (Hartree): 1.089482493071
# > Total ground state energy (Hartree): -7.864356161201
#
# === MEASURED OBSERVABLES ===
#
#
# === DIPOLE MOMENTS ===
#
# ~ Nuclear dipole moment (a.u.): [2.75360092  0.0  0.0]
#
#  Exact Energy: === GROUND STATE ENERGY ===
#
# * Electronic ground state energy (Hartree): -8.954100182855
#   - computed part:      -1.093021144531
#   - FreezeCoreTransformer extracted energy part: -7.861079038324
# ~ Nuclear repulsion energy (Hartree): 1.089482493071
# > Total ground state energy (Hartree): -7.864617689785
#
# === MEASURED OBSERVABLES ===
#
#
# === DIPOLE MOMENTS ===
#
# ~ Nuclear dipole moment (a.u.): [2.75360092  0.0  0.0]
#
#
# dist = np.float64(1.4612244897959183)
# = = = = = = = = = = = = = = = = = = = = = = = =
# Experiment started: 21:32:14
# . . . . . . . . . . . . . . . . . . .
#
# === GROUND STATE ENERGY ===
#
# * Electronic ground state energy (Hartree): -8.951149306256
#   - computed part:      -1.092102020375
#   - FreezeCoreTransformer extracted energy part: -7.859047285881
# ~ Nuclear repulsion energy (Hartree): 1.086439245883
# > Total ground state energy (Hartree): -7.864710060373
#
# === MEASURED OBSERVABLES ===
#
#
# === DIPOLE MOMENTS ===
#
# ~ Nuclear dipole moment (a.u.): [2.76131409  0.0  0.0]
#
# Exact solver done: 21:32:15
# ansatz initialized, 21:32:16
# ansatz.depth = 1
# num of qubits = 6
# VQE compute_minimum_eigenvalue done, 21:32:20
# VQE Result: === GROUND STATE ENERGY ===
#
# * Electronic ground state energy (Hartree): -8.950740423926
#   - computed part:      -1.091693138046
#   - FreezeCoreTransformer extracted energy part: -7.859047285881
# ~ Nuclear repulsion energy (Hartree): 1.086439245883
# > Total ground state energy (Hartree): -7.864301178043
#
# === MEASURED OBSERVABLES ===
#
#
# === DIPOLE MOMENTS ===
#
# ~ Nuclear dipole moment (a.u.): [2.76131409  0.0  0.0]
#
#  Exact Energy: === GROUND STATE ENERGY ===
#
# * Electronic ground state energy (Hartree): -8.951149306256
#   - computed part:      -1.092102020375
#   - FreezeCoreTransformer extracted energy part: -7.859047285881
# ~ Nuclear repulsion energy (Hartree): 1.086439245883
# > Total ground state energy (Hartree): -7.864710060373
#
# === MEASURED OBSERVABLES ===
#
#
# === DIPOLE MOMENTS ===
#
# ~ Nuclear dipole moment (a.u.): [2.76131409  0.0  0.0]
#
#
# dist = np.float64(1.4653061224489796)
# = = = = = = = = = = = = = = = = = = = = = = = =
# Experiment started: 21:32:20
# . . . . . . . . . . . . . . . . . . .
#
# === GROUND STATE ENERGY ===
#
# * Electronic ground state energy (Hartree): -8.948207435577
#   - computed part:      -1.091180388409
#   - FreezeCoreTransformer extracted energy part: -7.857027047168
# ~ Nuclear repulsion energy (Hartree): 1.083412952719
# > Total ground state energy (Hartree): -7.864794482858
#
# === MEASURED OBSERVABLES ===
#
#
# === DIPOLE MOMENTS ===
#
# ~ Nuclear dipole moment (a.u.): [2.76902726  0.0  0.0]
#
# Exact solver done: 21:32:21
# ansatz initialized, 21:32:21
# ansatz.depth = 1
# num of qubits = 6
# VQE compute_minimum_eigenvalue done, 21:32:25
# VQE Result: === GROUND STATE ENERGY ===
#
# * Electronic ground state energy (Hartree): -8.947677703205
#   - computed part:      -1.090650656036
#   - FreezeCoreTransformer extracted energy part: -7.857027047168
# ~ Nuclear repulsion energy (Hartree): 1.083412952719
# > Total ground state energy (Hartree): -7.864264750485
#
# === MEASURED OBSERVABLES ===
#
#
# === DIPOLE MOMENTS ===
#
# ~ Nuclear dipole moment (a.u.): [2.76902726  0.0  0.0]
#
#  Exact Energy: === GROUND STATE ENERGY ===
#
# * Electronic ground state energy (Hartree): -8.948207435577
#   - computed part:      -1.091180388409
#   - FreezeCoreTransformer extracted energy part: -7.857027047168
# ~ Nuclear repulsion energy (Hartree): 1.083412952719
# > Total ground state energy (Hartree): -7.864794482858
#
# === MEASURED OBSERVABLES ===
#
#
# === DIPOLE MOMENTS ===
#
# ~ Nuclear dipole moment (a.u.): [2.76902726  0.0  0.0]
#
#
# dist = np.float64(1.469387755102041)
# = = = = = = = = = = = = = = = = = = = = = = = =
# Experiment started: 21:32:25
# . . . . . . . . . . . . . . . . . . .
#
# === GROUND STATE ENERGY ===
#
# * Electronic ground state energy (Hartree): -8.945274523345
#   - computed part:      -1.090256301239
#   - FreezeCoreTransformer extracted energy part: -7.855018222106
# ~ Nuclear repulsion energy (Hartree): 1.080403472295
# > Total ground state energy (Hartree): -7.86487105105
#
# === MEASURED OBSERVABLES ===
#
#
# === DIPOLE MOMENTS ===
#
# ~ Nuclear dipole moment (a.u.): [2.77674043  0.0  0.0]
#
# Exact solver done: 21:32:26
# ansatz initialized, 21:32:26
# ansatz.depth = 1
# num of qubits = 6
# VQE compute_minimum_eigenvalue done, 21:32:31
# VQE Result: === GROUND STATE ENERGY ===
#
# * Electronic ground state energy (Hartree): -8.944684635979
#   - computed part:      -1.089666413873
#   - FreezeCoreTransformer extracted energy part: -7.855018222106
# ~ Nuclear repulsion energy (Hartree): 1.080403472295
# > Total ground state energy (Hartree): -7.864281163684
#
# === MEASURED OBSERVABLES ===
#
#
# === DIPOLE MOMENTS ===
#
# ~ Nuclear dipole moment (a.u.): [2.77674043  0.0  0.0]
#
#  Exact Energy: === GROUND STATE ENERGY ===
#
# * Electronic ground state energy (Hartree): -8.945274523345
#   - computed part:      -1.090256301239
#   - FreezeCoreTransformer extracted energy part: -7.855018222106
# ~ Nuclear repulsion energy (Hartree): 1.080403472295
# > Total ground state energy (Hartree): -7.86487105105
#
# === MEASURED OBSERVABLES ===
#
#
# === DIPOLE MOMENTS ===
#
# ~ Nuclear dipole moment (a.u.): [2.77674043  0.0  0.0]
#
#
# dist = np.float64(1.473469387755102)
# = = = = = = = = = = = = = = = = = = = = = = = =
# Experiment started: 21:32:31
# . . . . . . . . . . . . . . . . . . .
#
# === GROUND STATE ENERGY ===
#
# * Electronic ground state energy (Hartree): -8.942350522529
#   - computed part:      -1.089329810747
#   - FreezeCoreTransformer extracted energy part: -7.853020711782
# ~ Nuclear repulsion energy (Hartree): 1.077410664893
# > Total ground state energy (Hartree): -7.864939857636
#
# === MEASURED OBSERVABLES ===
#
#
# === DIPOLE MOMENTS ===
#
# ~ Nuclear dipole moment (a.u.): [2.7844536  0.0  0.0]
#
# Exact solver done: 21:32:32
# ansatz initialized, 21:32:32
# ansatz.depth = 1
# num of qubits = 6
# VQE compute_minimum_eigenvalue done, 21:32:36
# VQE Result: === GROUND STATE ENERGY ===
#
# * Electronic ground state energy (Hartree): -8.941762481457
#   - computed part:      -1.088741769675
#   - FreezeCoreTransformer extracted energy part: -7.853020711782
# ~ Nuclear repulsion energy (Hartree): 1.077410664893
# > Total ground state energy (Hartree): -7.864351816564
#
# === MEASURED OBSERVABLES ===
#
#
# === DIPOLE MOMENTS ===
#
# ~ Nuclear dipole moment (a.u.): [2.7844536  0.0  0.0]
#
#  Exact Energy: === GROUND STATE ENERGY ===
#
# * Electronic ground state energy (Hartree): -8.942350522529
#   - computed part:      -1.089329810747
#   - FreezeCoreTransformer extracted energy part: -7.853020711782
# ~ Nuclear repulsion energy (Hartree): 1.077410664893
# > Total ground state energy (Hartree): -7.864939857636
#
# === MEASURED OBSERVABLES ===
#
#
# === DIPOLE MOMENTS ===
#
# ~ Nuclear dipole moment (a.u.): [2.7844536  0.0  0.0]
#
#
# dist = np.float64(1.4775510204081632)
# = = = = = = = = = = = = = = = = = = = = = = = =
# Experiment started: 21:32:36
# . . . . . . . . . . . . . . . . . . .
#
# === GROUND STATE ENERGY ===
#
# * Electronic ground state energy (Hartree): -8.939435386564
#   - computed part:      -1.088400965447
#   - FreezeCoreTransformer extracted energy part: -7.851034421117
# ~ Nuclear repulsion energy (Hartree): 1.074434392338
# > Total ground state energy (Hartree): -7.865000994226
#
# === MEASURED OBSERVABLES ===
#
#
# === DIPOLE MOMENTS ===
#
# ~ Nuclear dipole moment (a.u.): [2.79216676  0.0  0.0]
#
# Exact solver done: 21:32:37
# ansatz initialized, 21:32:37
# ansatz.depth = 1
# num of qubits = 6
# VQE compute_minimum_eigenvalue done, 21:32:42
# VQE Result: === GROUND STATE ENERGY ===
#
# * Electronic ground state energy (Hartree): -8.939243821577
#   - computed part:      -1.08820940046
#   - FreezeCoreTransformer extracted energy part: -7.851034421117
# ~ Nuclear repulsion energy (Hartree): 1.074434392338
# > Total ground state energy (Hartree): -7.86480942924
#
# === MEASURED OBSERVABLES ===
#
#
# === DIPOLE MOMENTS ===
#
# ~ Nuclear dipole moment (a.u.): [2.79216676  0.0  0.0]
#
#  Exact Energy: === GROUND STATE ENERGY ===
#
# * Electronic ground state energy (Hartree): -8.939435386564
#   - computed part:      -1.088400965447
#   - FreezeCoreTransformer extracted energy part: -7.851034421117
# ~ Nuclear repulsion energy (Hartree): 1.074434392338
# > Total ground state energy (Hartree): -7.865000994226
#
# === MEASURED OBSERVABLES ===
#
#
# === DIPOLE MOMENTS ===
#
# ~ Nuclear dipole moment (a.u.): [2.79216676  0.0  0.0]
#
#
# dist = np.float64(1.4816326530612245)
# = = = = = = = = = = = = = = = = = = = = = = = =
# Experiment started: 21:32:42
# . . . . . . . . . . . . . . . . . . .
#
# === GROUND STATE ENERGY ===
#
# * Electronic ground state energy (Hartree): -8.936529069244
#   - computed part:      -1.087469821134
#   - FreezeCoreTransformer extracted energy part: -7.84905924811
# ~ Nuclear repulsion energy (Hartree): 1.071474517979
# > Total ground state energy (Hartree): -7.865054551265
#
# === MEASURED OBSERVABLES ===
#
#
# === DIPOLE MOMENTS ===
#
# ~ Nuclear dipole moment (a.u.): [2.79987993  0.0  0.0]
#
# Exact solver done: 21:32:43
# ansatz initialized, 21:32:43
# ansatz.depth = 1
# num of qubits = 6
# VQE compute_minimum_eigenvalue done, 21:32:47
# VQE Result: === GROUND STATE ENERGY ===
#
# * Electronic ground state energy (Hartree): -8.936296148313
#   - computed part:      -1.087236900203
#   - FreezeCoreTransformer extracted energy part: -7.84905924811
# ~ Nuclear repulsion energy (Hartree): 1.071474517979
# > Total ground state energy (Hartree): -7.864821630334
#
# === MEASURED OBSERVABLES ===
#
#
# === DIPOLE MOMENTS ===
#
# ~ Nuclear dipole moment (a.u.): [2.79987993  0.0  0.0]
#
#  Exact Energy: === GROUND STATE ENERGY ===
#
# * Electronic ground state energy (Hartree): -8.936529069244
#   - computed part:      -1.087469821134
#   - FreezeCoreTransformer extracted energy part: -7.84905924811
# ~ Nuclear repulsion energy (Hartree): 1.071474517979
# > Total ground state energy (Hartree): -7.865054551265
#
# === MEASURED OBSERVABLES ===
#
#
# === DIPOLE MOMENTS ===
#
# ~ Nuclear dipole moment (a.u.): [2.79987993  0.0  0.0]
#
#
# dist = np.float64(1.4857142857142858)
# = = = = = = = = = = = = = = = = = = = = = = = =
# Experiment started: 21:32:47
# . . . . . . . . . . . . . . . . . . .
#
# === GROUND STATE ENERGY ===
#
# * Electronic ground state energy (Hartree): -8.933631524859
#   - computed part:      -1.086536424918
#   - FreezeCoreTransformer extracted energy part: -7.847095099942
# ~ Nuclear repulsion energy (Hartree): 1.068530906665
# > Total ground state energy (Hartree): -7.865100618194
#
# === MEASURED OBSERVABLES ===
#
#
# === DIPOLE MOMENTS ===
#
# ~ Nuclear dipole moment (a.u.): [2.8075931  0.0  0.0]
#
# Exact solver done: 21:32:49
# ansatz initialized, 21:32:49
# ansatz.depth = 1
# num of qubits = 6
# VQE compute_minimum_eigenvalue done, 21:32:53
# VQE Result: === GROUND STATE ENERGY ===
#
# * Electronic ground state energy (Hartree): -8.933316942258
#   - computed part:      -1.086221842316
#   - FreezeCoreTransformer extracted energy part: -7.847095099942
# ~ Nuclear repulsion energy (Hartree): 1.068530906665
# > Total ground state energy (Hartree): -7.864786035593
#
# === MEASURED OBSERVABLES ===
#
#
# === DIPOLE MOMENTS ===
#
# ~ Nuclear dipole moment (a.u.): [2.8075931  0.0  0.0]
#
#  Exact Energy: === GROUND STATE ENERGY ===
#
# * Electronic ground state energy (Hartree): -8.933631524859
#   - computed part:      -1.086536424918
#   - FreezeCoreTransformer extracted energy part: -7.847095099942
# ~ Nuclear repulsion energy (Hartree): 1.068530906665
# > Total ground state energy (Hartree): -7.865100618194
#
# === MEASURED OBSERVABLES ===
#
#
# === DIPOLE MOMENTS ===
#
# ~ Nuclear dipole moment (a.u.): [2.8075931  0.0  0.0]
#
#
# dist = np.float64(1.489795918367347)
# = = = = = = = = = = = = = = = = = = = = = = = =
# Experiment started: 21:32:53
# . . . . . . . . . . . . . . . . . . .
#
# === GROUND STATE ENERGY ===
#
# * Electronic ground state energy (Hartree): -8.930742708103
#   - computed part:      -1.085600825894
#   - FreezeCoreTransformer extracted energy part: -7.845141882209
# ~ Nuclear repulsion energy (Hartree): 1.065603424729
# > Total ground state energy (Hartree): -7.865139283374
#
# === MEASURED OBSERVABLES ===
#
#
# === DIPOLE MOMENTS ===
#
# ~ Nuclear dipole moment (a.u.): [2.81530627  0.0  0.0]
#
# Exact solver done: 21:32:54
# ansatz initialized, 21:32:54
# ansatz.depth = 1
# num of qubits = 6
# VQE compute_minimum_eigenvalue done, 21:32:59
# VQE Result: === GROUND STATE ENERGY ===
#
# * Electronic ground state energy (Hartree): -8.929986418402
#   - computed part:      -1.084844536192
#   - FreezeCoreTransformer extracted energy part: -7.845141882209
# ~ Nuclear repulsion energy (Hartree): 1.065603424729
# > Total ground state energy (Hartree): -7.864382993672
#
# === MEASURED OBSERVABLES ===
#
#
# === DIPOLE MOMENTS ===
#
# ~ Nuclear dipole moment (a.u.): [2.81530627  0.0  0.0]
#
#  Exact Energy: === GROUND STATE ENERGY ===
#
# * Electronic ground state energy (Hartree): -8.930742708103
#   - computed part:      -1.085600825894
#   - FreezeCoreTransformer extracted energy part: -7.845141882209
# ~ Nuclear repulsion energy (Hartree): 1.065603424729
# > Total ground state energy (Hartree): -7.865139283374
#
# === MEASURED OBSERVABLES ===
#
#
# === DIPOLE MOMENTS ===
#
# ~ Nuclear dipole moment (a.u.): [2.81530627  0.0  0.0]
#
#
# dist = np.float64(1.493877551020408)
# = = = = = = = = = = = = = = = = = = = = = = = =
# Experiment started: 21:32:59
# . . . . . . . . . . . . . . . . . . .
#
# === GROUND STATE ENERGY ===
#
# * Electronic ground state energy (Hartree): -8.927862574085
#   - computed part:      -1.084663072487
#   - FreezeCoreTransformer extracted energy part: -7.843199501598
# ~ Nuclear repulsion energy (Hartree): 1.062691939962
# > Total ground state energy (Hartree): -7.865170634123
#
# === MEASURED OBSERVABLES ===
#
#
# === DIPOLE MOMENTS ===
#
# ~ Nuclear dipole moment (a.u.): [2.82301944  0.0  0.0]
#
# Exact solver done: 21:33:00
# ansatz initialized, 21:33:00
# ansatz.depth = 1
# num of qubits = 6
# VQE compute_minimum_eigenvalue done, 21:33:04
# VQE Result: === GROUND STATE ENERGY ===
#
# * Electronic ground state energy (Hartree): -8.927589188144
#   - computed part:      -1.084389686546
#   - FreezeCoreTransformer extracted energy part: -7.843199501598
# ~ Nuclear repulsion energy (Hartree): 1.062691939962
# > Total ground state energy (Hartree): -7.864897248182
#
# === MEASURED OBSERVABLES ===
#
#
# === DIPOLE MOMENTS ===
#
# ~ Nuclear dipole moment (a.u.): [2.82301944  0.0  0.0]
#
#  Exact Energy: === GROUND STATE ENERGY ===
#
# * Electronic ground state energy (Hartree): -8.927862574085
#   - computed part:      -1.084663072487
#   - FreezeCoreTransformer extracted energy part: -7.843199501598
# ~ Nuclear repulsion energy (Hartree): 1.062691939962
# > Total ground state energy (Hartree): -7.865170634123
#
# === MEASURED OBSERVABLES ===
#
#
# === DIPOLE MOMENTS ===
#
# ~ Nuclear dipole moment (a.u.): [2.82301944  0.0  0.0]
#
#
# dist = np.float64(1.4979591836734694)
# = = = = = = = = = = = = = = = = = = = = = = = =
# Experiment started: 21:33:04
# . . . . . . . . . . . . . . . . . . .
#
# === GROUND STATE ENERGY ===
#
# * Electronic ground state energy (Hartree): -8.924991078327
#   - computed part:      -1.083723212461
#   - FreezeCoreTransformer extracted energy part: -7.841267865866
# ~ Nuclear repulsion energy (Hartree): 1.059796321597
# > Total ground state energy (Hartree): -7.86519475673
#
# === MEASURED OBSERVABLES ===
#
#
# === DIPOLE MOMENTS ===
#
# ~ Nuclear dipole moment (a.u.): [2.8307326  0.0  0.0]
#
# Exact solver done: 21:33:05
# ansatz initialized, 21:33:06
# ansatz.depth = 1
# num of qubits = 6
# VQE compute_minimum_eigenvalue done, 21:33:10
# VQE Result: === GROUND STATE ENERGY ===
#
# * Electronic ground state energy (Hartree): -8.924168607655
#   - computed part:      -1.082900741789
#   - FreezeCoreTransformer extracted energy part: -7.841267865866
# ~ Nuclear repulsion energy (Hartree): 1.059796321597
# > Total ground state energy (Hartree): -7.864372286058
#
# === MEASURED OBSERVABLES ===
#
#
# === DIPOLE MOMENTS ===
#
# ~ Nuclear dipole moment (a.u.): [2.8307326  0.0  0.0]
#
#  Exact Energy: === GROUND STATE ENERGY ===
#
# * Electronic ground state energy (Hartree): -8.924991078327
#   - computed part:      -1.083723212461
#   - FreezeCoreTransformer extracted energy part: -7.841267865866
# ~ Nuclear repulsion energy (Hartree): 1.059796321597
# > Total ground state energy (Hartree): -7.86519475673
#
# === MEASURED OBSERVABLES ===
#
#
# === DIPOLE MOMENTS ===
#
# ~ Nuclear dipole moment (a.u.): [2.8307326  0.0  0.0]
#
#
# dist = np.float64(1.5020408163265306)
# = = = = = = = = = = = = = = = = = = = = = = = =
# Experiment started: 21:33:10
# . . . . . . . . . . . . . . . . . . .
#
# === GROUND STATE ENERGY ===
#
# * Electronic ground state energy (Hartree): -8.92212817676
#   - computed part:      -1.082781292929
#   - FreezeCoreTransformer extracted energy part: -7.839346883831
# ~ Nuclear repulsion energy (Hartree): 1.056916440289
# > Total ground state energy (Hartree): -7.865211736471
#
# === MEASURED OBSERVABLES ===
#
#
# === DIPOLE MOMENTS ===
#
# ~ Nuclear dipole moment (a.u.): [2.83844577  0.0  0.0]
#
# Exact solver done: 21:33:11
# ansatz initialized, 21:33:11
# ansatz.depth = 1
# num of qubits = 6
# VQE compute_minimum_eigenvalue done, 21:33:15
# VQE Result: === GROUND STATE ENERGY ===
#
# * Electronic ground state energy (Hartree): -8.921871960711
#   - computed part:      -1.08252507688
#   - FreezeCoreTransformer extracted energy part: -7.839346883831
# ~ Nuclear repulsion energy (Hartree): 1.056916440289
# > Total ground state energy (Hartree): -7.864955520422
#
# === MEASURED OBSERVABLES ===
#
#
# === DIPOLE MOMENTS ===
#
# ~ Nuclear dipole moment (a.u.): [2.83844577  0.0  0.0]
#
#  Exact Energy: === GROUND STATE ENERGY ===
#
# * Electronic ground state energy (Hartree): -8.92212817676
#   - computed part:      -1.082781292929
#   - FreezeCoreTransformer extracted energy part: -7.839346883831
# ~ Nuclear repulsion energy (Hartree): 1.056916440289
# > Total ground state energy (Hartree): -7.865211736471
#
# === MEASURED OBSERVABLES ===
#
#
# === DIPOLE MOMENTS ===
#
# ~ Nuclear dipole moment (a.u.): [2.83844577  0.0  0.0]
#
#
# dist = np.float64(1.506122448979592)
# = = = = = = = = = = = = = = = = = = = = = = = =
# Experiment started: 21:33:15
# . . . . . . . . . . . . . . . . . . .
#
# === GROUND STATE ENERGY ===
#
# * Electronic ground state energy (Hartree): -8.919273825716
#   - computed part:      -1.081837360363
#   - FreezeCoreTransformer extracted energy part: -7.837436465353
# ~ Nuclear repulsion energy (Hartree): 1.054052168093
# > Total ground state energy (Hartree): -7.865221657623
#
# === MEASURED OBSERVABLES ===
#
#
# === DIPOLE MOMENTS ===
#
# ~ Nuclear dipole moment (a.u.): [2.84615894  0.0  0.0]
#
# Exact solver done: 21:33:16
# ansatz initialized, 21:33:17
# ansatz.depth = 1
# num of qubits = 6
# VQE compute_minimum_eigenvalue done, 21:33:21
# VQE Result: === GROUND STATE ENERGY ===
#
# * Electronic ground state energy (Hartree): -8.918976133182
#   - computed part:      -1.081539667829
#   - FreezeCoreTransformer extracted energy part: -7.837436465353
# ~ Nuclear repulsion energy (Hartree): 1.054052168093
# > Total ground state energy (Hartree): -7.86492396509
#
# === MEASURED OBSERVABLES ===
#
#
# === DIPOLE MOMENTS ===
#
# ~ Nuclear dipole moment (a.u.): [2.84615894  0.0  0.0]
#
#  Exact Energy: === GROUND STATE ENERGY ===
#
# * Electronic ground state energy (Hartree): -8.919273825716
#   - computed part:      -1.081837360363
#   - FreezeCoreTransformer extracted energy part: -7.837436465353
# ~ Nuclear repulsion energy (Hartree): 1.054052168093
# > Total ground state energy (Hartree): -7.865221657623
#
# === MEASURED OBSERVABLES ===
#
#
# === DIPOLE MOMENTS ===
#
# ~ Nuclear dipole moment (a.u.): [2.84615894  0.0  0.0]
#
#
# dist = np.float64(1.510204081632653)
# = = = = = = = = = = = = = = = = = = = = = = = =
# Experiment started: 21:33:21
# . . . . . . . . . . . . . . . . . . .
#
# === GROUND STATE ENERGY ===
#
# * Electronic ground state energy (Hartree): -8.916427981925
#   - computed part:      -1.080891460601
#   - FreezeCoreTransformer extracted energy part: -7.835536521323
# ~ Nuclear repulsion energy (Hartree): 1.051203378449
# > Total ground state energy (Hartree): -7.865224603476
#
# === MEASURED OBSERVABLES ===
#
#
# === DIPOLE MOMENTS ===
#
# ~ Nuclear dipole moment (a.u.): [2.85387211  0.0  0.0]
#
# Exact solver done: 21:33:22
# ansatz initialized, 21:33:22
# ansatz.depth = 1
# num of qubits = 6
# VQE compute_minimum_eigenvalue done, 21:33:27
# VQE Result: === GROUND STATE ENERGY ===
#
# * Electronic ground state energy (Hartree): -8.916048078196
#   - computed part:      -1.080511556873
#   - FreezeCoreTransformer extracted energy part: -7.835536521323
# ~ Nuclear repulsion energy (Hartree): 1.051203378449
# > Total ground state energy (Hartree): -7.864844699747
#
# === MEASURED OBSERVABLES ===
#
#
# === DIPOLE MOMENTS ===
#
# ~ Nuclear dipole moment (a.u.): [2.85387211  0.0  0.0]
#
#  Exact Energy: === GROUND STATE ENERGY ===
#
# * Electronic ground state energy (Hartree): -8.916427981925
#   - computed part:      -1.080891460601
#   - FreezeCoreTransformer extracted energy part: -7.835536521323
# ~ Nuclear repulsion energy (Hartree): 1.051203378449
# > Total ground state energy (Hartree): -7.865224603476
#
# === MEASURED OBSERVABLES ===
#
#
# === DIPOLE MOMENTS ===
#
# ~ Nuclear dipole moment (a.u.): [2.85387211  0.0  0.0]
#
#
# dist = np.float64(1.5142857142857142)
# = = = = = = = = = = = = = = = = = = = = = = = =
# Experiment started: 21:33:27
# . . . . . . . . . . . . . . . . . . .
#
# === GROUND STATE ENERGY ===
#
# * Electronic ground state energy (Hartree): -8.913590602509
#   - computed part:      -1.079943638861
#   - FreezeCoreTransformer extracted energy part: -7.833646963649
# ~ Nuclear repulsion energy (Hartree): 1.048369946162
# > Total ground state energy (Hartree): -7.865220656347
#
# === MEASURED OBSERVABLES ===
#
#
# === DIPOLE MOMENTS ===
#
# ~ Nuclear dipole moment (a.u.): [2.86158527  0.0  0.0]
#
# Exact solver done: 21:33:28
# ansatz initialized, 21:33:28
# ansatz.depth = 1
# num of qubits = 6
# VQE compute_minimum_eigenvalue done, 21:33:32
# VQE Result: === GROUND STATE ENERGY ===
#
# * Electronic ground state energy (Hartree): -8.913236834811
#   - computed part:      -1.079589871162
#   - FreezeCoreTransformer extracted energy part: -7.833646963649
# ~ Nuclear repulsion energy (Hartree): 1.048369946162
# > Total ground state energy (Hartree): -7.864866888649
#
# === MEASURED OBSERVABLES ===
#
#
# === DIPOLE MOMENTS ===
#
# ~ Nuclear dipole moment (a.u.): [2.86158527  0.0  0.0]
#
#  Exact Energy: === GROUND STATE ENERGY ===
#
# * Electronic ground state energy (Hartree): -8.913590602509
#   - computed part:      -1.079943638861
#   - FreezeCoreTransformer extracted energy part: -7.833646963649
# ~ Nuclear repulsion energy (Hartree): 1.048369946162
# > Total ground state energy (Hartree): -7.865220656347
#
# === MEASURED OBSERVABLES ===
#
#
# === DIPOLE MOMENTS ===
#
# ~ Nuclear dipole moment (a.u.): [2.86158527  0.0  0.0]
#
#
# dist = np.float64(1.5183673469387755)
# = = = = = = = = = = = = = = = = = = = = = = = =
# Experiment started: 21:33:32
# . . . . . . . . . . . . . . . . . . .
#
# === GROUND STATE ENERGY ===
#
# * Electronic ground state energy (Hartree): -8.91076164498
#   - computed part:      -1.078993939744
#   - FreezeCoreTransformer extracted energy part: -7.831767705236
# ~ Nuclear repulsion energy (Hartree): 1.045551747382
# > Total ground state energy (Hartree): -7.865209897598
#
# === MEASURED OBSERVABLES ===
#
#
# === DIPOLE MOMENTS ===
#
# ~ Nuclear dipole moment (a.u.): [2.86929844  0.0  0.0]
#
# Exact solver done: 21:33:33
# ansatz initialized, 21:33:33
# ansatz.depth = 1
# num of qubits = 6
# VQE compute_minimum_eigenvalue done, 21:33:38
# VQE Result: === GROUND STATE ENERGY ===
#
# * Electronic ground state energy (Hartree): -8.910407135668
#   - computed part:      -1.078639430432
#   - FreezeCoreTransformer extracted energy part: -7.831767705236
# ~ Nuclear repulsion energy (Hartree): 1.045551747382
# > Total ground state energy (Hartree): -7.864855388286
#
# === MEASURED OBSERVABLES ===
#
#
# === DIPOLE MOMENTS ===
#
# ~ Nuclear dipole moment (a.u.): [2.86929844  0.0  0.0]
#
#  Exact Energy: === GROUND STATE ENERGY ===
#
# * Electronic ground state energy (Hartree): -8.91076164498
#   - computed part:      -1.078993939744
#   - FreezeCoreTransformer extracted energy part: -7.831767705236
# ~ Nuclear repulsion energy (Hartree): 1.045551747382
# > Total ground state energy (Hartree): -7.865209897598
#
# === MEASURED OBSERVABLES ===
#
#
# === DIPOLE MOMENTS ===
#
# ~ Nuclear dipole moment (a.u.): [2.86929844  0.0  0.0]
#
#
# dist = np.float64(1.5224489795918368)
# = = = = = = = = = = = = = = = = = = = = = = = =
# Experiment started: 21:33:38
# . . . . . . . . . . . . . . . . . . .
#
# === GROUND STATE ENERGY ===
#
# * Electronic ground state energy (Hartree): -8.907941067231
#   - computed part:      -1.07804240725
#   - FreezeCoreTransformer extracted energy part: -7.829898659981
# ~ Nuclear repulsion energy (Hartree): 1.042748659588
# > Total ground state energy (Hartree): -7.865192407643
#
# === MEASURED OBSERVABLES ===
#
#
# === DIPOLE MOMENTS ===
#
# ~ Nuclear dipole moment (a.u.): [2.87701161  0.0  0.0]
#
# Exact solver done: 21:33:39
# ansatz initialized, 21:33:39
# ansatz.depth = 1
# num of qubits = 6
# ...
# ~ Nuclear repulsion energy (Hartree): 1.018181282791
# > Total ground state energy (Hartree): -7.864744910863
#
# === MEASURED OBSERVABLES ===
#
#
# === DIPOLE MOMENTS ===
#
# ~ Nuclear dipole moment (a.u.): [2.94643012  0.0  0.0]
#
#
# dist = np.float64(1.563265306122449)
# = = = = = = = = = = = = = = = = = = = = = = = =
# Experiment started: 21:34:35
# . . . . . . . . . . . . . . . . . . .
#
# === GROUND STATE ENERGY ===
#
# * Electronic ground state energy (Hartree): -8.88018717882
#   - computed part:      -1.068435511148
#   - FreezeCoreTransformer extracted energy part: -7.811751667672
# ~ Nuclear repulsion energy (Hartree): 1.015522846021
# > Total ground state energy (Hartree): -7.864664332799
#
# === MEASURED OBSERVABLES ===
#
#
# === DIPOLE MOMENTS ===
#
# ~ Nuclear dipole moment (a.u.): [2.95414329  0.0  0.0]
#
# Exact solver done: 21:34:36
# ansatz initialized, 21:34:36
# ansatz.depth = 1
# num of qubits = 6
# VQE compute_minimum_eigenvalue done, 21:34:40
# VQE Result: === GROUND STATE ENERGY ===
#
# * Electronic ground state energy (Hartree): -8.87962475674
#   - computed part:      -1.067873089068
#   - FreezeCoreTransformer extracted energy part: -7.811751667672
# ~ Nuclear repulsion energy (Hartree): 1.015522846021
# > Total ground state energy (Hartree): -7.864101910718
#
# === MEASURED OBSERVABLES ===
#
#
# === DIPOLE MOMENTS ===
#
# ~ Nuclear dipole moment (a.u.): [2.95414329  0.0  0.0]
#
#  Exact Energy: === GROUND STATE ENERGY ===
#
# * Electronic ground state energy (Hartree): -8.88018717882
#   - computed part:      -1.068435511148
#   - FreezeCoreTransformer extracted energy part: -7.811751667672
# ~ Nuclear repulsion energy (Hartree): 1.015522846021
# > Total ground state energy (Hartree): -7.864664332799
#
# === MEASURED OBSERVABLES ===
#
#
# === DIPOLE MOMENTS ===
#
# ~ Nuclear dipole moment (a.u.): [2.95414329  0.0  0.0]
#
#
# dist = np.float64(1.5673469387755103)
# = = = = = = = = = = = = = = = = = = = = = = = =
# Experiment started: 21:34:40
# . . . . . . . . . . . . . . . . . . .
#
# === GROUND STATE ENERGY ===
#
# * Electronic ground state energy (Hartree): -8.877456104566
#   - computed part:      -1.067466551038
#   - FreezeCoreTransformer extracted energy part: -7.809989553527
# ~ Nuclear repulsion energy (Hartree): 1.012878255277
# > Total ground state energy (Hartree): -7.864577849289
#
# === MEASURED OBSERVABLES ===
#
#
# === DIPOLE MOMENTS ===
#
# ~ Nuclear dipole moment (a.u.): [2.96185646  0.0  0.0]
#
# Exact solver done: 21:34:41
# ansatz initialized, 21:34:41
# ansatz.depth = 1
# num of qubits = 6
# VQE compute_minimum_eigenvalue done, 21:34:46
# VQE Result: === GROUND STATE ENERGY ===
#
# * Electronic ground state energy (Hartree): -8.877259543816
#   - computed part:      -1.067269990288
#   - FreezeCoreTransformer extracted energy part: -7.809989553527
# ~ Nuclear repulsion energy (Hartree): 1.012878255277
# > Total ground state energy (Hartree): -7.864381288539
#
# === MEASURED OBSERVABLES ===
#
#
# === DIPOLE MOMENTS ===
#
# ~ Nuclear dipole moment (a.u.): [2.96185646  0.0  0.0]
#
#  Exact Energy: === GROUND STATE ENERGY ===
#
# * Electronic ground state energy (Hartree): -8.877456104566
#   - computed part:      -1.067466551038
#   - FreezeCoreTransformer extracted energy part: -7.809989553527
# ~ Nuclear repulsion energy (Hartree): 1.012878255277
# > Total ground state energy (Hartree): -7.864577849289
#
# === MEASURED OBSERVABLES ===
#
#
# === DIPOLE MOMENTS ===
#
# ~ Nuclear dipole moment (a.u.): [2.96185646  0.0  0.0]
#
#
# dist = np.float64(1.5714285714285716)
# = = = = = = = = = = = = = = = = = = = = = = = =
# Experiment started: 21:34:46
# . . . . . . . . . . . . . . . . . . .
#
# === GROUND STATE ENERGY ===
#
# * Electronic ground state energy (Hartree): -8.87473293303
#   - computed part:      -1.066496241449
#   - FreezeCoreTransformer extracted energy part: -7.808236691581
# ~ Nuclear repulsion energy (Hartree): 1.010247402665
# > Total ground state energy (Hartree): -7.864485530365
#
# === MEASURED OBSERVABLES ===
#
#
# === DIPOLE MOMENTS ===
#
# ~ Nuclear dipole moment (a.u.): [2.96956962  0.0  0.0]
#
# Exact solver done: 21:34:47
# ansatz initialized, 21:34:47
# ansatz.depth = 1
# num of qubits = 6
# VQE compute_minimum_eigenvalue done, 21:34:51
# VQE Result: === GROUND STATE ENERGY ===
#
# * Electronic ground state energy (Hartree): -8.874566155121
#   - computed part:      -1.06632946354
#   - FreezeCoreTransformer extracted energy part: -7.808236691581
# ~ Nuclear repulsion energy (Hartree): 1.010247402665
# > Total ground state energy (Hartree): -7.864318752455
#
# === MEASURED OBSERVABLES ===
#
#
# === DIPOLE MOMENTS ===
#
# ~ Nuclear dipole moment (a.u.): [2.96956962  0.0  0.0]
#
#  Exact Energy: === GROUND STATE ENERGY ===
#
# * Electronic ground state energy (Hartree): -8.87473293303
#   - computed part:      -1.066496241449
#   - FreezeCoreTransformer extracted energy part: -7.808236691581
# ~ Nuclear repulsion energy (Hartree): 1.010247402665
# > Total ground state energy (Hartree): -7.864485530365
#
# === MEASURED OBSERVABLES ===
#
#
# === DIPOLE MOMENTS ===
#
# ~ Nuclear dipole moment (a.u.): [2.96956962  0.0  0.0]
#
#
# dist = np.float64(1.5755102040816327)
# = = = = = = = = = = = = = = = = = = = = = = = =
# Experiment started: 21:34:51
# . . . . . . . . . . . . . . . . . . .
#
# === GROUND STATE ENERGY ===
#
# * Electronic ground state energy (Hartree): -8.872017626676
#   - computed part:      -1.065524619274
#   - FreezeCoreTransformer extracted energy part: -7.806493007403
# ~ Nuclear repulsion energy (Hartree): 1.007630181415
# > Total ground state energy (Hartree): -7.864387445261
#
# === MEASURED OBSERVABLES ===
#
#
# === DIPOLE MOMENTS ===
#
# ~ Nuclear dipole moment (a.u.): [2.97728279  0.0  0.0]
#
# Exact solver done: 21:34:53
# ansatz initialized, 21:34:53
# ansatz.depth = 1
# num of qubits = 6
# VQE compute_minimum_eigenvalue done, 21:34:57
# VQE Result: === GROUND STATE ENERGY ===
#
# * Electronic ground state energy (Hartree): -8.871568811521
#   - computed part:      -1.065075804118
#   - FreezeCoreTransformer extracted energy part: -7.806493007403
# ~ Nuclear repulsion energy (Hartree): 1.007630181415
# > Total ground state energy (Hartree): -7.863938630106
#
# === MEASURED OBSERVABLES ===
#
#
# === DIPOLE MOMENTS ===
#
# ~ Nuclear dipole moment (a.u.): [2.97728279  0.0  0.0]
#
#  Exact Energy: === GROUND STATE ENERGY ===
#
# * Electronic ground state energy (Hartree): -8.872017626676
#   - computed part:      -1.065524619274
#   - FreezeCoreTransformer extracted energy part: -7.806493007403
# ~ Nuclear repulsion energy (Hartree): 1.007630181415
# > Total ground state energy (Hartree): -7.864387445261
#
# === MEASURED OBSERVABLES ===
#
#
# === DIPOLE MOMENTS ===
#
# ~ Nuclear dipole moment (a.u.): [2.97728279  0.0  0.0]
#
#
# dist = np.float64(1.579591836734694)
# = = = = = = = = = = = = = = = = = = = = = = = =
# Experiment started: 21:34:57
# . . . . . . . . . . . . . . . . . . .
#
# === GROUND STATE ENERGY ===
#
# * Electronic ground state energy (Hartree): -8.86931014829
#   - computed part:      -1.06455172091
#   - FreezeCoreTransformer extracted energy part: -7.80475842738
# ~ Nuclear repulsion energy (Hartree): 1.005026485856
# > Total ground state energy (Hartree): -7.864283662434
#
# === MEASURED OBSERVABLES ===
#
#
# === DIPOLE MOMENTS ===
#
# ~ Nuclear dipole moment (a.u.): [2.98499596  0.0  0.0]
#
# Exact solver done: 21:34:58
# ansatz initialized, 21:34:58
# ansatz.depth = 1
# num of qubits = 6
# VQE compute_minimum_eigenvalue done, 21:35:03
# VQE Result: === GROUND STATE ENERGY ===
#
# * Electronic ground state energy (Hartree): -8.868476010445
#   - computed part:      -1.063717583065
#   - FreezeCoreTransformer extracted energy part: -7.80475842738
# ~ Nuclear repulsion energy (Hartree): 1.005026485856
# > Total ground state energy (Hartree): -7.863449524589
#
# === MEASURED OBSERVABLES ===
#
#
# === DIPOLE MOMENTS ===
#
# ~ Nuclear dipole moment (a.u.): [2.98499596  0.0  0.0]
#
#  Exact Energy: === GROUND STATE ENERGY ===
#
# * Electronic ground state energy (Hartree): -8.86931014829
#   - computed part:      -1.06455172091
#   - FreezeCoreTransformer extracted energy part: -7.80475842738
# ~ Nuclear repulsion energy (Hartree): 1.005026485856
# > Total ground state energy (Hartree): -7.864283662434
#
# === MEASURED OBSERVABLES ===
#
#
# === DIPOLE MOMENTS ===
#
# ~ Nuclear dipole moment (a.u.): [2.98499596  0.0  0.0]
#
#
# dist = np.float64(1.5836734693877552)
# = = = = = = = = = = = = = = = = = = = = = = = =
# Experiment started: 21:35:03
# . . . . . . . . . . . . . . . . . . .
#
# === GROUND STATE ENERGY ===
#
# * Electronic ground state energy (Hartree): -8.866610460974
#   - computed part:      -1.063577582273
#   - FreezeCoreTransformer extracted energy part: -7.803032878701
# ~ Nuclear repulsion energy (Hartree): 1.002436211408
# > Total ground state energy (Hartree): -7.864174249566
#
# === MEASURED OBSERVABLES ===
#
#
# === DIPOLE MOMENTS ===
#
# ~ Nuclear dipole moment (a.u.): [2.99270913  0.0  0.0]
#
# Exact solver done: 21:35:04
# ansatz initialized, 21:35:04
# ansatz.depth = 1
# num of qubits = 6
# VQE compute_minimum_eigenvalue done, 21:35:08
# VQE Result: === GROUND STATE ENERGY ===
#
# * Electronic ground state energy (Hartree): -8.86613988344
#   - computed part:      -1.063107004739
#   - FreezeCoreTransformer extracted energy part: -7.803032878701
# ~ Nuclear repulsion energy (Hartree): 1.002436211408
# > Total ground state energy (Hartree): -7.863703672032
#
# === MEASURED OBSERVABLES ===
#
#
# === DIPOLE MOMENTS ===
#
# ~ Nuclear dipole moment (a.u.): [2.99270913  0.0  0.0]
#
#  Exact Energy: === GROUND STATE ENERGY ===
#
# * Electronic ground state energy (Hartree): -8.866610460974
#   - computed part:      -1.063577582273
#   - FreezeCoreTransformer extracted energy part: -7.803032878701
# ~ Nuclear repulsion energy (Hartree): 1.002436211408
# > Total ground state energy (Hartree): -7.864174249566
#
# === MEASURED OBSERVABLES ===
#
#
# === DIPOLE MOMENTS ===
#
# ~ Nuclear dipole moment (a.u.): [2.99270913  0.0  0.0]
#
#
# dist = np.float64(1.5877551020408165)
# = = = = = = = = = = = = = = = = = = = = = = = =
# Experiment started: 21:35:08
# . . . . . . . . . . . . . . . . . . .
#
# === GROUND STATE ENERGY ===
#
# * Electronic ground state energy (Hartree): -8.863918528147
#   - computed part:      -1.062602238796
#   - FreezeCoreTransformer extracted energy part: -7.801316289351
# ~ Nuclear repulsion energy (Hartree): 0.999859254566
# > Total ground state energy (Hartree): -7.864059273581
#
# === MEASURED OBSERVABLES ===
#
#
# === DIPOLE MOMENTS ===
#
# ~ Nuclear dipole moment (a.u.): [3.0004223  0.0  0.0]
#
# Exact solver done: 21:35:10
# ansatz initialized, 21:35:10
# ansatz.depth = 1
# num of qubits = 6
# VQE compute_minimum_eigenvalue done, 21:35:14
# VQE Result: === GROUND STATE ENERGY ===
#
# * Electronic ground state energy (Hartree): -8.863576428248
#   - computed part:      -1.062260138897
#   - FreezeCoreTransformer extracted energy part: -7.801316289351
# ~ Nuclear repulsion energy (Hartree): 0.999859254566
# > Total ground state energy (Hartree): -7.863717173682
#
# === MEASURED OBSERVABLES ===
#
#
# === DIPOLE MOMENTS ===
#
# ~ Nuclear dipole moment (a.u.): [3.0004223  0.0  0.0]
#
#  Exact Energy: === GROUND STATE ENERGY ===
#
# * Electronic ground state energy (Hartree): -8.863918528147
#   - computed part:      -1.062602238796
#   - FreezeCoreTransformer extracted energy part: -7.801316289351
# ~ Nuclear repulsion energy (Hartree): 0.999859254566
# > Total ground state energy (Hartree): -7.864059273581
#
# === MEASURED OBSERVABLES ===
#
#
# === DIPOLE MOMENTS ===
#
# ~ Nuclear dipole moment (a.u.): [3.0004223  0.0  0.0]
#
#
# dist = np.float64(1.5918367346938775)
# = = = = = = = = = = = = = = = = = = = = = = = =
# Experiment started: 21:35:14
# . . . . . . . . . . . . . . . . . . .
#
# === GROUND STATE ENERGY ===
#
# * Electronic ground state energy (Hartree): -8.861234313535
#   - computed part:      -1.06162572544
#   - FreezeCoreTransformer extracted energy part: -7.799608588095
# ~ Nuclear repulsion energy (Hartree): 0.997295512888
# > Total ground state energy (Hartree): -7.863938800647
#
# === MEASURED OBSERVABLES ===
#
#
# === DIPOLE MOMENTS ===
#
# ~ Nuclear dipole moment (a.u.): [3.00813546  0.0  0.0]
#
# Exact solver done: 21:35:15
# ansatz initialized, 21:35:15
# ansatz.depth = 1
# num of qubits = 6
# VQE compute_minimum_eigenvalue done, 21:35:20
# VQE Result: === GROUND STATE ENERGY ===
#
# * Electronic ground state energy (Hartree): -8.860532919424
#   - computed part:      -1.06092433133
#   - FreezeCoreTransformer extracted energy part: -7.799608588095
# ~ Nuclear repulsion energy (Hartree): 0.997295512888
# > Total ground state energy (Hartree): -7.863237406537
#
# === MEASURED OBSERVABLES ===
#
#
# === DIPOLE MOMENTS ===
#
# ~ Nuclear dipole moment (a.u.): [3.00813546  0.0  0.0]
#
#  Exact Energy: === GROUND STATE ENERGY ===
#
# * Electronic ground state energy (Hartree): -8.861234313535
#   - computed part:      -1.06162572544
#   - FreezeCoreTransformer extracted energy part: -7.799608588095
# ~ Nuclear repulsion energy (Hartree): 0.997295512888
# > Total ground state energy (Hartree): -7.863938800647
#
# === MEASURED OBSERVABLES ===
#
#
# === DIPOLE MOMENTS ===
#
# ~ Nuclear dipole moment (a.u.): [3.00813546  0.0  0.0]
#
#
# dist = np.float64(1.5959183673469388)
# = = = = = = = = = = = = = = = = = = = = = = = =
# Experiment started: 21:35:20
# . . . . . . . . . . . . . . . . . . .
#
# === GROUND STATE ENERGY ===
#
# * Electronic ground state energy (Hartree): -8.858557781172
#   - computed part:      -1.060648076702
#   - FreezeCoreTransformer extracted energy part: -7.79790970447
# ~ Nuclear repulsion energy (Hartree): 0.994744884977
# > Total ground state energy (Hartree): -7.863812896195
#
# === MEASURED OBSERVABLES ===
#
#
# === DIPOLE MOMENTS ===
#
# ~ Nuclear dipole moment (a.u.): [3.01584863  0.0  0.0]
#
# Exact solver done: 21:35:21
# ansatz initialized, 21:35:21
# ansatz.depth = 1
# num of qubits = 6
# VQE compute_minimum_eigenvalue done, 21:35:25
# VQE Result: === GROUND STATE ENERGY ===
#
# * Electronic ground state energy (Hartree): -8.857560219295
#   - computed part:      -1.059650514825
#   - FreezeCoreTransformer extracted energy part: -7.79790970447
# ~ Nuclear repulsion energy (Hartree): 0.994744884977
# > Total ground state energy (Hartree): -7.862815334318
#
# === MEASURED OBSERVABLES ===
#
#
# === DIPOLE MOMENTS ===
#
# ~ Nuclear dipole moment (a.u.): [3.01584863  0.0  0.0]
#
#  Exact Energy: === GROUND STATE ENERGY ===
#
# * Electronic ground state energy (Hartree): -8.858557781172
#   - computed part:      -1.060648076702
#   - FreezeCoreTransformer extracted energy part: -7.79790970447
# ~ Nuclear repulsion energy (Hartree): 0.994744884977
# > Total ground state energy (Hartree): -7.863812896195
#
# === MEASURED OBSERVABLES ===
#
#
# === DIPOLE MOMENTS ===
#
# ~ Nuclear dipole moment (a.u.): [3.01584863  0.0  0.0]
#
#
# dist = np.float64(1.6)
# = = = = = = = = = = = = = = = = = = = = = = = =
# Experiment started: 21:35:25
# . . . . . . . . . . . . . . . . . . .
#
# === GROUND STATE ENERGY ===
#
# * Electronic ground state energy (Hartree): -8.855888895396
#   - computed part:      -1.059669326619
#   - FreezeCoreTransformer extracted energy part: -7.796219568777
# ~ Nuclear repulsion energy (Hartree): 0.992207270475
# > Total ground state energy (Hartree): -7.863681624921
#
# === MEASURED OBSERVABLES ===
#
#
# === DIPOLE MOMENTS ===
#
# ~ Nuclear dipole moment (a.u.): [3.0235618  0.0  0.0]
#
# Exact solver done: 21:35:26
# ansatz initialized, 21:35:27
# ansatz.depth = 1
# num of qubits = 6
# VQE compute_minimum_eigenvalue done, 21:35:31
# VQE Result: === GROUND STATE ENERGY ===
#
# * Electronic ground state energy (Hartree): -8.855456310507
#   - computed part:      -1.05923674173
#   - FreezeCoreTransformer extracted energy part: -7.796219568777
# ~ Nuclear repulsion energy (Hartree): 0.992207270475
# > Total ground state energy (Hartree): -7.863249040032
#
# === MEASURED OBSERVABLES ===
#
#
# === DIPOLE MOMENTS ===
#
# ~ Nuclear dipole moment (a.u.): [3.0235618  0.0  0.0]
#
#  Exact Energy: === GROUND STATE ENERGY ===
#
# * Electronic ground state energy (Hartree): -8.855888895396
#   - computed part:      -1.059669326619
#   - FreezeCoreTransformer extracted energy part: -7.796219568777
# ~ Nuclear repulsion energy (Hartree): 0.992207270475
# > Total ground state energy (Hartree): -7.863681624921
#
# === MEASURED OBSERVABLES ===
#
#
# === DIPOLE MOMENTS ===
#
# ~ Nuclear dipole moment (a.u.): [3.0235618  0.0  0.0]

# %%
exact_energies_fixed = []
vqe_energies_fixed = []
for el, vl in zip(exact_energies,vqe_energies):
  exact_energies_fixed.append(el.electronic_energies[0] + el.nuclear_repulsion_energy)
  vqe_energies_fixed.append(vl.electronic_energies[0] + vl.nuclear_repulsion_energy)

# %%
import matplotlib.pyplot as plt

index = 0

plt.figure(figsize=(10, 6))
plt.plot(lioh_dist_domain[index:], exact_energies_fixed[index:], label='Exact solver', linestyle='-', color='b')
plt.plot(lioh_dist_domain[index:], vqe_energies_fixed[index:], label='VQE', linestyle='dashdot', color='r')
plt.title('LiH')
plt.grid()
plt.legend(loc='best')
plt.show()

# %%
# The error commited at every step remain small

fig, ax = plt.subplots()
# ax.plot(lioh_dist_domain,np.log10(np.abs([vqe_energies[i] - exact_energies_fixed[i] for i in range(len(lioh_dist_domain))])),'+--')
ax.plot(lioh_dist_domain,(np.abs([vqe_energies[i].electronic_energies[0] - exact_energies[i].electronic_energies[0] for i in range(len(lioh_dist_domain))])),'+--')

ax.set_xlabel("Distance")
ax.set_ylabel("Error")
plt.draw()

# %%
exact_energies_fixed = []
vqe_energies_fixed = []
error_total = []
error_electron = []
error_nuclear = []
for el, vl in zip(exact_energies,vqe_energies):
  error_total.append(np.abs(el.total_energies - vl.total_energies))
  error_nuclear.append(np.abs(el.nuclear_repulsion_energy - vl.nuclear_repulsion_energy))
  error_electron.append(np.abs(el.electronic_energies[0] - vl.electronic_energies[0]))
  
import matplotlib.pyplot as plt

index = 0

plt.figure(figsize=(10, 6))
plt.plot(lioh_dist_domain[index:], error_total[index:], label='total error', linestyle='-', color='b')
plt.plot(lioh_dist_domain[index:], error_nuclear[index:], label='nuclear error', linestyle='dashdot', color='r')
plt.plot(lioh_dist_domain[index:], error_electron[index:], label='electron error', linestyle='dotted', color='g')
plt.title('LiH')
plt.grid()
plt.legend(loc='best')
plt.show()
